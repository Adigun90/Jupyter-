# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_excel('OYOCENTRAL2.xlsx')

# %%
df
# Out:
#     S/N      NAME OF CANDIDATE GENDER PARTY  VOTES RECEIVED  REMARK
# 0     1   AJITADIDUN ELIZABETH      M     A             799    Loss
# 1     2   OLUMUYIWA .A. SUNDAY      F    AD             599    Loss
# 2     3    SUNMONU J. MONSURAT      M   ADC           41657    Loss
# 3     4       SUGAR OLATOYE .T      M   ADP           41377    Loss
# 4     5       TOPE O. OJERINDE      M  ANRP            1033    Loss
# 5     6       FOLARIN TESLIM K      M   APC           91080  WINNER
# 6     7   OLUKAYODE A. STEPHEN      M   DPC             437    Loss
# 7     8          OYERINDE JOHN      M   DPP             511    Loss
# 8     9       OYEBODE O. MOSES      M   HDP             108    Loss
# 9    10   SALAUDEEN J. ADEBAYO      M    ID              95    Loss
# 10   11        LAMIDI B. APAPA      M    LP             308    Loss
# 11   12     SUNDAY A. KOLAWALE      M   MPN             202    Loss
# 12   13     LATEEF K. KOLAWALE      M   NCP             254    Loss
# ...

# %%
df.describe()
# Out:
#              S/N  VOTES RECEIVED
# count  21.000000       21.000000
# mean   11.000000    12975.285714
# std     6.204837    27609.872001
# min     1.000000       77.000000
# 25%     6.000000      254.000000
# 50%    11.000000      599.000000
# 75%    16.000000     1327.000000
# max    21.000000    91080.000000

# %%
df.dtypes
# Out:
# S/N                   int64
# NAME OF CANDIDATE    object
# GENDER               object
# PARTY                object
# VOTES RECEIVED        int64
# REMARK               object
# dtype: object

# %%
df.sum()
# Out:
# S/N                                                                231
# NAME OF CANDIDATE    AJITADIDUN ELIZABETHOLUMUYIWA .A. SUNDAYSUNMON...
# GENDER                                           MFMMMMMMMMMMMMMMMMMMM
# PARTY                AADADCADPANRPAPCDPCDPPHDPIDLPMPNNCPNPCNRMPDPPP...
# VOTES RECEIVED                                                  272481
# REMARK               LossLossLossLossLossWINNERLossLossLossLossLoss...
# dtype: object

# %%
## Total number of casted vote
df['VOTES RECEIVED'].sum()
# Out:
# 272481

# %%
df.plot.area()
plt.figure(figsize=[8,7])

# %% [markdown]
#  ## The graph below show the winner of the election of 2019 senatorial district of Oyo State (Oyo Central)

# %%
import seaborn as sns

# %%
plt.figure(figsize=[15,5.5])
sns.barplot(x='PARTY', y='VOTES RECEIVED', data=df)
# Out:
# <AxesSubplot:xlabel='PARTY', ylabel='VOTES RECEIVED'>

# %%
df['VOTES RECEIVED']. plot(kind='pie', figsize=(50,50))
# Out:
# <AxesSubplot:ylabel='VOTES RECEIVED'>

# %%
sns.lmplot(x='S/N',y='VOTES RECEIVED', data=df, hue='GENDER', scatter_kws={'s':100})

# %%
pip install jupyterthemes
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t onedork
